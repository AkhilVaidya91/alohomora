# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAXResults
import statsmodels.api as sm
import pickle
import os

# %%
## loading all the models

facewash_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\models\facewash.pkl', 'rb'))
fairy_lights_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\models\fairy_lights.pkl', 'rb'))
necklace_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\models\necklace.pkl', 'rb'))
notebook_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\models\notebook.pkl', 'rb'))
rice_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\models\rice.pkl', 'rb'))

# %%
## loading all the datasets

facewash = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\facewash.csv')
fairy_lights = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\fairy_lights.csv')
necklace = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\necklace.csv')
notebook = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\notebook.csv')
rice = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\rice.csv')

# %%
data['forecast'] = model_fit.predict(start=0, end=156)
data[['sales', 'forecast']].plot(figsize=(12, 8))

# %%
facewash['forecast'] = facewash_model.predict(start=0, end=156)
fairy_lights['forecast'] = fairy_lights_model.predict(start=0, end=156)
necklace['forecast'] = necklace_model.predict(start=0, end=156)
notebook['forecast'] = notebook_model.predict(start=0, end=156)
rice['forecast'] = rice_model.predict(start=0, end=207)

# %%
facewash[['facewash', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
fairy_lights[['fairy_lights', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
necklace[['necklace', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
notebook[['notebook', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
rice[['rice', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %% [markdown]
# ### __LOOKS GOOD !!!__
