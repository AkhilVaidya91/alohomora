# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAXResults
import statsmodels.api as sm
import pickle
import os

# %%
## loading all the models

facewash_model = pickle.load(open(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora-git\demand forecasting\models\facewash_arima.pkl', 'rb'))

# %%
## loading all the datasets

facewash = pd.read_csv(r'C:\Users\Akhil PC\Documents\Walmart Hackathon\alohomora\demand forecasting\data\facewash.csv')

# %%
facewash['forecast'] = facewash_model.predict(start=0, end=156)

# %%
facewash[['facewash', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
## calculating the mse for facewash model

mse_facewash = ((facewash['facewash'][100:] - facewash['forecast'][100:]) ** 2).mean()
mse_facewash
# Out:
# 9.17886140255093
